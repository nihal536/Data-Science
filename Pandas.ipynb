# %%
import pandas as pd

df1 = pd.read_csv('first_file.csv')

df1
# Out:
#     Id   Age  Height  Weight
# 0  101  24.0     175      85
# 1  102  25.0     165      72
# 2  103  30.0     168      75
# 3  104   NaN     172      79
# 4  105  28.0     170      76

# %%
df2 = pd.read_csv('second_file.csv')

df2
# Out:
#     Id  Age  Height  Weight
# 0  201   24     178      67
# 1  202   23     170      76
# 2  203   22     168      80
# 3  204   21     165      81
# 4  205   26     171      82

# %%
df3 = pd.read_csv('third_file.csv')

df3
# Out:
#   Gender   BP
# 0      M  120
# 1      F  140
# 2      M  145
# 3      F  132
# 4      M  130
# 5      F  150
# 6      M  147
# 7      F  132
# 8      M  128
# 9      F  130

# %%
df1
# Out:
#     Id   Age  Height  Weight
# 0  101  24.0     175      85
# 1  102  25.0     165      72
# 2  103  30.0     168      75
# 3  104   NaN     172      79
# 4  105  28.0     170      76

# %%
int(df1['Age'].mean())
# Out:
# 26

# %%
df1['Age']=df1['Age'].fillna(int(df1['Age'].mean()))

# %%
df1
# Out:
#     Id   Age  Height  Weight
# 0  101  24.0     175      85
# 1  102  25.0     165      72
# 2  103  30.0     168      75
# 3  104  26.0     172      79
# 4  105  28.0     170      76

# %%
#let's see what's their in df2

# %%
df2
# Out:
#     Id  Age  Height  Weight
# 0  201   24     178      67
# 1  202   23     170      76
# 2  203   22     168      80
# 3  204   21     165      81
# 4  205   26     171      82

# %%
#Two different files but variables looks like the same.
#rows concatinating

# %%
df4 = pd.concat([df1,df2],ignore_index=True)

# %%
df4
# Out:
#     Id   Age  Height  Weight
# 0  101  24.0     175      85
# 1  102  25.0     165      72
# 2  103  30.0     168      75
# 3  104  26.0     172      79
# 4  105  28.0     170      76
# 5  201  24.0     178      67
# 6  202  23.0     170      76
# 7  203  22.0     168      80
# 8  204  21.0     165      81
# 9  205  26.0     171      82

# %%
# let's see what's their in df3

# %%
df3
# Out:
#   Gender   BP
# 0      M  120
# 1      F  140
# 2      M  145
# 3      F  132
# 4      M  130
# 5      F  150
# 6      M  147
# 7      F  132
# 8      M  128
# 9      F  130

# %%
#looks like variables are different in both df3 and df4, but rows are same
# columns concatinating

# %%
df5 = pd.concat([df4,df3],axis=1)

# %% [markdown]
# df5

# %%
df5
# Out:
#     Id   Age  Height  Weight Gender   BP
# 0  101  24.0     175      85      M  120
# 1  102  25.0     165      72      F  140
# 2  103  30.0     168      75      M  145
# 3  104  26.0     172      79      F  132
# 4  105  28.0     170      76      M  130
# 5  201  24.0     178      67      F  150
# 6  202  23.0     170      76      M  147
# 7  203  22.0     168      80      F  132
# 8  204  21.0     165      81      M  128
# 9  205  26.0     171      82      F  130

# %%
#groupby

# %%
df5['Age'].mean()
# Out:
# np.float64(24.9)

# %%
"""How can we calculate the separate means for both Male and Female individually
---Using Groupby"""
# Out:
# 'How can we calculate the separate means for both Male and Female individually\n---Using Groupby'

# %%
df5.groupby("Gender")["Age"].mean()
# Out:
# Gender
# F    24.6
# M    25.2
# Name: Age, dtype: float64
