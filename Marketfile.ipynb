# %%
import pandas as pd

# %%
df = pd.read_csv("Market_Dataset.csv")
df
# Out:
#      Region          Product  Subsidiaries  Stores   Sales  Inventory  Returns
# 0     North      Electronics             5      20  250000       1200       50
# 1     South        Groceries             3      15  180000        900       34
# 2      East         Clothing             4      25  200000        700       37
# 3      West        Furniture             6      18  210000        500       25
# 4   Central    Mobile Phones             5      23  300000       1500       60
# 5     North          Laptops             6      25  220000        800       50
# 6     South  Home Appliances             3      14  175000        650       18
# 7      East         Footwear             2       9  130000        450       20
# 8      West            Books             4      25  190000        250       45
# 9   Central             Toys             5      11  150000        350       40
# 10    North          Watches             3      17  230000        250       30
# ...

# %%
df["Region"].value_counts()
# Out:
# Region
# North      3
# South      3
# East       3
# West       3
# Central    2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Region        14 non-null     str
#  1   Product       14 non-null     str
#  2   Subsidiaries  14 non-null     int64
#  3   Stores        14 non-null     int64
#  4   Sales         14 non-null     int64
#  5   Inventory     14 non-null     int64
#  6   Returns       14 non-null     int64
# dtypes: int64(5), str(2)
# memory usage: 916.0 bytes

# %%
df["Sales"].sum()
# Out:
# np.int64(2865000)

# %%
#regions and sales
#which region contains highest sales

# %%
t1 = df.groupby("Region")['Sales'].sum()

# %%
t1
# Out:
# Region
# Central    450000
# East       530000
# North      700000
# South      575000
# West       610000
# Name: Sales, dtype: int64

# %%
t2 = t1.sort_values() #ascending order,ascending = False

# %%
t2
# Out:
# Region
# Central    450000
# East       530000
# South      575000
# West       610000
# North      700000
# Name: Sales, dtype: int64

# %%
t2.plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
t1.plot(kind='pie')
# Out:
# <Axes: >

# %%
# creating the Histogram:

# %%
df["Sales"].hist()
# Out:
# <Axes: >

# %%
# Create a boxplot using pandas

# %%
boxplot= df["Sales"].plot(kind = 'box',vert=False,title='Boxplot')

# %%
#Create a Scatterplot using Panads

# %%
scatter= df.plot(kind='scatter',x='Sales',y='Returns',title='scatterplot')
