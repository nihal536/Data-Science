# %%
import numpy as np
age = np.array([24,28,32,34,36])
age
# Out:
# array([24, 28, 32, 34, 36])

# %%
#-----------------------------------------------

# %%
import numpy as np
age = np.array([[24],[28],[32],[34],[36]])
age
# Out:
# array([[24],
#        [28],
#        [32],
#        [34],
#        [36]])

# %%
#---------------------------------------------------

# %%
data = np.array([[24,170,84,100],[28,168,80,120],[32,171,75,105],[34,170,78,108],[36,164,80,100]])
data
# Out:
# array([[ 24, 170,  84, 100],
#        [ 28, 168,  80, 120],
#        [ 32, 171,  75, 105],
#        [ 34, 170,  78, 108],
#        [ 36, 164,  80, 100]])

# %%
# row,column ---Selecting row and column
data [ : , 0:1]   # selecting the age column
# Out:
# array([[24],
#        [28],
#        [32],
#        [34],
#        [36]])

# %%
np.mean(data[ : , 0:1])
# Calculating the average of a specific column

print("Mean:",np.mean(data[ : , 0:1]))
print("Median:",np.median(data[ : , 0:1]))
print("Standard deviation:",np.std(data[ : , 0:1]))
print("Varience:",np.var(data[ : , 0:1]))
# Out:
# Mean: 30.8
# Median: 32.0
# Standard deviation: 4.308131845707603
# Varience: 18.56

# %%
data[ : , 0:2]  # selecting multiple columns
# Out:
# array([[ 24, 170],
#        [ 28, 168],
#        [ 32, 171],
#        [ 34, 170],
#        [ 36, 164]])

# %%
data[ : , 0:3:2]
# Out:
# array([[24, 84],
#        [28, 80],
#        [32, 75],
#        [34, 78],
#        [36, 80]])

# %%
# Creating the data in 1D []-1D, [[]]=2D

# %%
x1= np.random.randint(10,20,size=6)   #One dimensional array
x1
# Out:
# array([16, 13, 12, 14, 10, 18], dtype=int32)

# %%
x1.ndim    #To find out which dimension is it
# Out:
# 1

# %%
# Creating the data in 2D

# %%
x2= np.random.randint(10,20,size=(3,4))   #Two dimensional array
x2
# Out:
# array([[15, 13, 11, 12],
#        [17, 13, 17, 15],
#        [19, 12, 12, 17]], dtype=int32)

# %%
x2.ndim
# Out:
# 2

# %%
# Creating the data in 3D

# %%
x3= np.random.randint(10,20,size=(2,3,4))
x3
# Out:
# array([[[15, 19, 19, 18],
#         [12, 18, 11, 15],
#         [16, 19, 13, 14]],
#
#        [[13, 17, 12, 15],
#         [15, 13, 14, 18],
#         [10, 18, 19, 19]]], dtype=int32)

# %%
x3.ndim
# Out:
# 3

# %%
data
# Out:
# array([[ 24, 170,  84, 100],
#        [ 28, 168,  80, 120],
#        [ 32, 171,  75, 105],
#        [ 34, 170,  78, 108],
#        [ 36, 164,  80, 100]])

# %%
type(data)
# Out:
# numpy.ndarray

# %%
#======================================================================================================

# %%
#PANDAS- It is a datascience library written in Python,Use to work in Dataset,Displays the data in Tabular format

# %%
data
# Out:
# array([[ 24, 170,  84, 100],
#        [ 28, 168,  80, 120],
#        [ 32, 171,  75, 105],
#        [ 34, 170,  78, 108],
#        [ 36, 164,  80, 100]])

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#     0    1   2    3
# 0  24  170  84  100
# 1  28  168  80  120
# 2  32  171  75  105
# 3  34  170  78  108
# 4  36  164  80  100

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.columns=["Age","Height","Weight","BP"]
df
# Out:
#    Age  Height  Weight   BP
# 0   24     170      84  100
# 1   28     168      80  120
# 2   32     171      75  105
# 3   34     170      78  108
# 4   36     164      80  100

# %%
df.index=["a","b","c","d","e"]
df
# Out:
#    Age  Height  Weight   BP
# a   24     170      84  100
# b   28     168      80  120
# c   32     171      75  105
# d   34     170      78  108
# e   36     164      80  100

# %%
print("Mean:", df["BP"].mean())
print("Median:",df["BP"].median())
print("Mode:",df["BP"].mode())
print("standard deviation:",df["BP"].std())
print("Variance:",df["BP"].var())
# Out:
# Mean: 106.6
# Median: 105.0
# Mode: 0    100
# Name: BP, dtype: int64
# standard deviation: 8.23407554009556
# Variance: 67.8

# %%
df["BP"].describe()
# Out:
# count      5.000000
# mean     106.600000
# std        8.234076
# min      100.000000
# 25%      100.000000
# 50%      105.000000
# 75%      108.000000
# max      120.000000
# Name: BP, dtype: float64
